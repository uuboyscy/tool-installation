# %%
'''
CarouselContainerJsonDict
For items on sale
'''

# %%
tmp = """
    {

        "type": "carousel",
        "contents": [ 
            {
                "type": "bubble",
                "header": {
                    "type": "box",
                    "layout": "vertical",
                    "flex": 0,
                    "contents": [
                        {
                            "type": "text",
                            "text": "ＭＥＭＢＥＲ ＣＥＮＴＲＥ",
                            "size": "lg",
                            "align": "center",
                            "gravity": "center",
                            "weight": "bold",
                            "color": "#000000"
                        }
                    ]
                },
                "hero": {
                    "type": "image",
                    "url": "%s",
                    "size": "full",
                    "aspectRatio": "20:13",
                    "aspectMode": "cover",
                    "action": {
                        "type": "uri",
                        "label": "Action",
                        "uri": "https://linecorp.com"
                    }
                },
                "body": {
                    "type": "box",
                    "layout": "vertical",
                    "spacing": "md",
                    "action": {
                        "type": "uri",
                        "label": "Action",
                        "uri": "https://linecorp.com"
                    },
                    "contents": [
                        {
                            "type": "text",
                            "text": "User ID",
                            "size": "lg",
                            "weight": "bold",
                            "color": "#000000"
                        },
                        {
                            "type": "text",
                            "text": "%s",
                            "size": "md"
                        },
                        {
                            "type": "text",
                            "text": "User Name",
                            "size": "lg",
                            "weight": "bold",
                            "color": "#000000",
                            "wrap": true
                        },
                        {
                            "type": "text",
                            "text": "%s",
                            "align": "start"
                        }
                    ]
                },
                "footer": {
                    "type": "box",
                    "layout": "vertical",
                    "contents": [
                        {
                            "type": "spacer",
                            "size": "xxl"
                        },
                        {
                            "type": "button",
                            "action": {
                                "type": "message",
                                "label": "Modify",
                                "text": "Modify"
                            },
                            "color": "#905C44",
                            "style": "primary"
                        }
                    ]
                }
            }
        ]
}"""
tmp%("vhjckxhvjkcxhjvkcx","vhcxjkvhcjxhvjkcx","hjxkzhcjxkzhcjkxz")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-13-c3e042bd79be> in <module>
#      94         ]
#      95 }"""
# ---> 96 tmp%(vhjckxhvjkcxhjvkcx,vhcxjkvhcjxhvjkcx,hjxkzhcjxkzhcjkxz)
#
# NameError: name 'vhjckxhvjkcxhjvkcx' is not defined

# %%
if __name__ == '__main__':
    print(member_centre("qrcode", "userid", "name"))
# Out:
#         {
#         "type": "bubble",
#         "header": {
#           "type": "box",
#           "layout": "vertical",
#           "flex": 0,
#           "contents": [
#             {
#               "type": "text",
#               "text": "ＭＥＭＢＥＲ ＣＥＮＴＲＥ",
#               "align": "center",
#               "gravity": "center",
#               "weight": "bold",
#               "color": "#000000"
#             }
#           ]
#         },
#         "hero": {
#           "type": "image",
#           "url": "qrcode",
#           "size": "full",
#           "aspectRatio": "20:13",
#           "aspectMode": "cover",
#           "action": {
#             "type": "uri",
#             "label": "Action",
#             "uri": "https://linecorp.com"
#           }
#         },
#         "body": {
#           "type": "box",
#           "layout": "vertical",
#           "spacing": "md",
#           "action": {
#             "type": "uri",
#             "label": "Action",
#             "uri": "https://linecorp.com"
#           },
#           "contents": [
#             {
#               "type": "text",
#               "text": "User ID",
#               "size": "lg",
#               "weight": "bold",
#               "color": "#000000"
#             },
#             {
#               "type": "text",
#               "text": "userid",
#               "size": "md"
#             },
#             {
#               "type": "text",
#               "text": "User Name",
#               "size": "lg",
#               "weight": "bold",
#               "color": "#000000",
#               "wrap": true
#             },
#             {
#               "type": "text",
#               "text": "name",
#               "align": "start"
#             }
#           ]
#         },
#         "footer": {
#           "type": "box",
#           "layout": "vertical",
#           "contents": [
#             {
#               "type": "spacer",
#               "size": "xxl"
#             },
#             {
#               "type": "button",
#               "action": {
#                 "type": "message",
#                 "label": "Modify",
#                 "text": "Modify"
#               },
#               "color": "#905C44",
#               "style": "primary"
#             }
#           ]
#         }
#       }
